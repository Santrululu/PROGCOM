# %%
class Estudiante:
    def __init__(self, nombre):
        self.nombre = nombre
        self._nota1 = 0
        self._nota2 = 0
        self._nota3 = 0

    @property
    def nota1(self):
        return self._nota1

    @nota1.setter
    def nota1(self, valor):
        if 0 <= valor <= 100:
            self._nota1 = valor
        else:
            raise ValueError("La nota debe estar entre 0 y 100.")

    @property
    def nota2(self):
        return self._nota2

    @nota2.setter
    def nota2(self, valor):
        if 0 <= valor <= 100:
            self._nota2 = valor
        else:
            raise ValueError("La nota debe estar entre 0 y 100.")

    @property
    def nota3(self):
        return self._nota3

    @nota3.setter
    def nota3(self, valor):
        if 0 <= valor <= 100:
            self._nota3 = valor
        else:
            raise ValueError("La nota debe estar entre 0 y 100.")

    def calcular_nota_final(self):
        if self.nota1 >= 70 and self.nota2 >= 70 and self.nota3 >= 70:
            return (self.nota1 + self.nota2 + self.nota3) / 3
        else:
            return None


class Salon:
    def __init__(self):
        self.estudiantes = []

    def agregar_estudiante(self, estudiante):
        self.estudiantes.append(estudiante)

    def imprimir_reporte(self):
        print("\nREPORTE DE CALIFICACIONES")
        print("NOMBRE\tNOTA1\tNOTA2\tNOTA3\tNOTA FINAL")
        print("--------------------------------------------------")

        for estudiante in self.estudiantes:
            nota_final = estudiante.calcular_nota_final()
            if nota_final is not None:
                print(f"{estudiante.nombre}\t{estudiante.nota1}\t{estudiante.nota2}\t{estudiante.nota3}\t{nota_final:.2f}")
            else:
                print(f"{estudiante.nombre}\t{estudiante.nota1}\t{estudiante.nota2}\t{estudiante.nota3}\tNA (No Acreditado)")

        total_estudiantes = len(self.estudiantes)
        print(f"\nTOTAL {total_estudiantes} ESTUDIANTES")
        print(total_estudiantes)


# Programa principal
def main():
    salon = Salon()

    for i in range(28):
        print(f"Ingrese los datos del estudiante {i + 1}:")
        nombre = input("Nombre del estudiante: ")
        estudiante = Estudiante(nombre)

        estudiante.nota1 = float(input("Nota 1: "))
        estudiante.nota2 = float(input("Nota 2: "))
        estudiante.nota3 = float(input("Nota 3: "))


        salon.agregar_estudiante(estudiante)

    salon.imprimir_reporte()


if __name__ == "__main__":
    main()
# Out:
# Ingrese los datos del estudiante 1:
# Nombre del estudiante: santiago
# Nota 1: 30
# Nota 2: 60
# Nota 3: 50
# Ingrese los datos del estudiante 2:
# Nombre del estudiante: jorge
# Nota 1: 20
# Nota 2: 10
# Nota 3: 40
# Ingrese los datos del estudiante 3:
# Nombre del estudiante: celis
# Nota 1: 1
# Nota 2: 1
# Nota 3: 1
# Ingrese los datos del estudiante 4:
# Nombre del estudiante: si
# Nota 1: 2
# Nota 2: 3
# Nota 3: 4
# Ingrese los datos del estudiante 5:
# Nombre del estudiante: 2
# Nota 1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-fc25a8102ddf> in <cell line: 91>()
#      90
#      91 if __name__ == "__main__":
# ---> 92     main()
#      93
#
# <ipython-input-1-fc25a8102ddf> in main()
#      79         estudiante = Estudiante(nombre)
#      80
# ---> 81         estudiante.nota1 = float(input("Nota 1: "))
#      82         estudiante.nota2 = float(input("Nota 2: "))
#      83         estudiante.nota3 = float(input("Nota 3: "))
#
# ValueError: could not convert string to float: ''
